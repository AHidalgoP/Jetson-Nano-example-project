# %%
# Import tensorflow and print current version
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
# Import rest of libraries used in the code. Usually this is done at the beginning of the document but it can be done at any position
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.optimizers import SGD, Adagrad, Adadelta
from keras.utils import np_utils
from keras.callbacks import LearningRateScheduler
import os

# %%
# Hyperparameters:
# They must be carefully select depending on the dataset and model

NB_EPOCH =  30      # Number of training epochs
VALIDATION_SPLIT=0.2 # Size of the validation split taken from the training set. If your dataset has validation split, skip this part.

# %% [markdown]
# Cargamos el dataset:

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
PATH_OF_DATA= '/content/gdrive/MyDrive/casa'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/gdrive/MyDrive/casa', labels='inferred', subset="training", validation_split=VALIDATION_SPLIT, seed=0)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/gdrive/MyDrive/casa', labels='inferred', subset="validation", validation_split=VALIDATION_SPLIT, seed=0)
# Out:
# Found 160 files belonging to 8 classes.
# Using 128 files for training.
# Found 160 files belonging to 8 classes.
# Using 32 files for validation.

# %%
train_ds
# Out:
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# Vamos a visualizar una de las muestras y la clase a la que pertenece:

# %%
import matplotlib.pyplot as plt
sample = list(train_ds.as_numpy_iterator())[0]    # Tupla con el batch
image = sample[0]                                 # Batch de imagenes
label = sample[1]                                 # Batch de labels
plt.imshow(np.squeeze(image[0])/255.0)
print(label[0])
# Out:
# 5

# %%
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    image = tf.image.resize(image,(256,256))
    return image,label

train_ds = train_ds.map(process)
val_ds = val_ds.map(process)

# %%
# Create a pretrained model.
model = tf.keras.applications.MobileNet(
  include_top=False, weights='imagenet', input_shape=(256,256,3), classes=8)

# Freeze weights
for l in model.layers:
  l.trainable=False;

# Add new classification layer
flat = tf.keras.layers.Flatten()(model.output)
out = tf.keras.layers.Dense(8, activation='softmax')(flat)

model = tf.keras.models.Model(inputs=model.inputs, outputs=out)

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 128, 128, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 128, 128, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 128, 128, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 128, 128, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 128, 128, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 128, 128, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 128, 128, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 128, 128, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 129, 129, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 64, 64, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 64, 64, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 64, 64, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 64, 64, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 64, 64, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 64, 64, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 64, 64, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 64, 64, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 64, 64, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 64, 64, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 64, 64, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 64, 64, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 65, 65, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 32, 32, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 32, 32, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 32, 32, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 32, 32, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 32, 32, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 32, 32, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 32, 32, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 32, 32, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 32, 32, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 33, 33, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 16, 16, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 16, 16, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 16, 16, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 16, 16, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 16, 16, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 16, 16, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 16, 16, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 16, 16, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 16, 16, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 16, 16, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 16, 16, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 16, 16, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 16, 16, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 16, 16, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 17, 17, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 8, 8, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 8, 8, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 8, 8, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 8, 8, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 8, 8, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 8, 8, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 8, 8, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 8, 8, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 8, 8, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 8, 8, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 8, 8, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 524296
# =================================================================
# Total params: 3,753,160
# Trainable params: 524,296
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_ds, epochs=NB_EPOCH, validation_data=val_ds)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 18s 3s/step - loss: 9.9518 - accuracy: 0.2156 - val_loss: 11.1798 - val_accuracy: 0.3750
# Epoch 2/30
# 4/4 [==============================] - 2s 192ms/step - loss: 2.2956 - accuracy: 0.8042 - val_loss: 6.7284 - val_accuracy: 0.6875
# Epoch 3/30
# 4/4 [==============================] - 1s 175ms/step - loss: 0.8377 - accuracy: 0.9021 - val_loss: 2.1276 - val_accuracy: 0.8750
# Epoch 4/30
# 4/4 [==============================] - 1s 173ms/step - loss: 1.7385e-09 - accuracy: 1.0000 - val_loss: 2.2923 - val_accuracy: 0.8438
# Epoch 5/30
# 4/4 [==============================] - 1s 176ms/step - loss: 1.2418e-09 - accuracy: 1.0000 - val_loss: 3.2407 - val_accuracy: 0.6875
# Epoch 6/30
# 4/4 [==============================] - 1s 174ms/step - loss: 1.9868e-09 - accuracy: 1.0000 - val_loss: 4.3359 - val_accuracy: 0.6562
# Epoch 7/30
# 4/4 [==============================] - 1s 176ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 5.2574 - val_accuracy: 0.6562
# Epoch 8/30
# 4/4 [==============================] - 1s 173ms/step - loss: 1.2790e-08 - accuracy: 1.0000 - val_loss: 5.9148 - val_accuracy: 0.6562
# Epoch 9/30
# 4/4 [==============================] - 1s 176ms/step - loss: 2.8511e-07 - accuracy: 1.0000 - val_loss: 6.3691 - val_accuracy: 0.6562
# Epoch 10/30
# 4/4 [==============================] - 1s 179ms/step - loss: 3.5978e-06 - accuracy: 1.0000 - val_loss: 6.6820 - val_accuracy: 0.6562
# Epoch 11/30
# 4/4 [==============================] - 1s 176ms/step - loss: 1.7227e-05 - accuracy: 1.0000 - val_loss: 6.8966 - val_accuracy: 0.6562
# Epoch 12/30
# 4/4 [==============================] - 1s 172ms/step - loss: 1.9553e-05 - accuracy: 1.0000 - val_loss: 7.0431 - val_accuracy: 0.6562
# Epoch 13/30
# 4/4 [==============================] - 1s 180ms/step - loss: 1.4904e-05 - accuracy: 1.0000 - val_loss: 7.1412 - val_accuracy: 0.6562
# Epoch 14/30
# 4/4 [==============================] - 1s 171ms/step - loss: 5.6091e-05 - accuracy: 1.0000 - val_loss: 7.2054 - val_accuracy: 0.6562
# Epoch 15/30
# 4/4 [==============================] - 1s 174ms/step - loss: 4.2893e-06 - accuracy: 1.0000 - val_loss: 7.2488 - val_accuracy: 0.6562
# Epoch 16/30
# 4/4 [==============================] - 1s 183ms/step - loss: 1.0823e-06 - accuracy: 1.0000 - val_loss: 7.2780 - val_accuracy: 0.6562
# Epoch 17/30
# 4/4 [==============================] - 1s 176ms/step - loss: 2.1929e-06 - accuracy: 1.0000 - val_loss: 7.2976 - val_accuracy: 0.6562
# Epoch 18/30
# 4/4 [==============================] - 1s 171ms/step - loss: 2.6840e-06 - accuracy: 1.0000 - val_loss: 7.3107 - val_accuracy: 0.6562
# Epoch 19/30
# 4/4 [==============================] - 1s 179ms/step - loss: 1.8891e-06 - accuracy: 1.0000 - val_loss: 7.3195 - val_accuracy: 0.6562
# Epoch 20/30
# 4/4 [==============================] - 1s 174ms/step - loss: 4.9644e-07 - accuracy: 1.0000 - val_loss: 7.3254 - val_accuracy: 0.6562
# Epoch 21/30
# 4/4 [==============================] - 1s 172ms/step - loss: 2.6064e-07 - accuracy: 1.0000 - val_loss: 7.3292 - val_accuracy: 0.6562
# Epoch 22/30
# 4/4 [==============================] - 1s 179ms/step - loss: 1.0697e-06 - accuracy: 1.0000 - val_loss: 7.3318 - val_accuracy: 0.6562
# Epoch 23/30
# 4/4 [==============================] - 1s 175ms/step - loss: 3.4793e-07 - accuracy: 1.0000 - val_loss: 7.3334 - val_accuracy: 0.6562
# Epoch 24/30
# 4/4 [==============================] - 1s 175ms/step - loss: 8.9330e-07 - accuracy: 1.0000 - val_loss: 7.3345 - val_accuracy: 0.6562
# Epoch 25/30
# 4/4 [==============================] - 1s 178ms/step - loss: 4.7881e-07 - accuracy: 1.0000 - val_loss: 7.3351 - val_accuracy: 0.6562
# Epoch 26/30
# 4/4 [==============================] - 1s 170ms/step - loss: 1.7223e-07 - accuracy: 1.0000 - val_loss: 7.3355 - val_accuracy: 0.6562
# Epoch 27/30
# 4/4 [==============================] - 1s 185ms/step - loss: 2.9144e-07 - accuracy: 1.0000 - val_loss: 7.3357 - val_accuracy: 0.6562
# Epoch 28/30
# 4/4 [==============================] - 1s 175ms/step - loss: 2.7256e-07 - accuracy: 1.0000 - val_loss: 7.3358 - val_accuracy: 0.6562
# Epoch 29/30
# 4/4 [==============================] - 1s 174ms/step - loss: 2.7641e-07 - accuracy: 1.0000 - val_loss: 7.3357 - val_accuracy: 0.6562
# Epoch 30/30
# 4/4 [==============================] - 1s 179ms/step - loss: 1.5211e-07 - accuracy: 1.0000 - val_loss: 7.3357 - val_accuracy: 0.6562

# %%
model.evaluate(val_ds)
# Out:
# 1/1 [==============================] - 0s 333ms/step - loss: 7.3357 - accuracy: 0.6562
# [7.335707664489746, 0.65625]

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Save model
OUT_MODEL_PATH= '/content/gdrive/MyDrive/Curso-Jetson/models'
model.save(os.path.join(OUT_MODEL_PATH, 'model-final-pract2.hdf5'))
model.save(os.path.join(OUT_MODEL_PATH, 'model-final-pract2'))
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Curso-Jetson/models/model-final-pract2/assets

# %%
# !ls $OUT_MODEL_PATH
# Out:
# model-final-pract2  model-final-pract2.hdf5
